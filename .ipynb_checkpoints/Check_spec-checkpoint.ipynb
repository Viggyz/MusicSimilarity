# %%
import librosa
import librosa.display
import glob
import numpy as np
import matplotlib.pyplot as plt
from numpy import save
import os
import sys
import time,logging
from pathlib import Path
from PIL import Image

from functools import partial
from matplotlib.pyplot import imshow

# %%
name = "000005"
melspec = np.load("precalculated_files_mel\\fma_numpy\\%s.npy" % name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-ac8a015d2f28> in <module>
#       1 name = "000005"
# ----> 2 melspec = np.load("precalculated_files_mel\\fma_numpy\\%s.npy" % name)
#
# c:\python38\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: 'precalculated_files_mel\\fma_numpy\\000005.npy'

# %%
melspec.shape
# Out:
# (128, 1293)

# %%
librosa.display.specshow(librosa.power_to_db(melspec, ref=np.max), y_axis='mel', fmax=8000, x_axis='time')
plt.axis('off')
# Out:
# (-0.011609977324263039,
#  30.011791383219954,
#  -11.875496186856948,
#  8096.785216670944)

# %%
new_mel = librosa.power_to_db(melspec)

# %%
new_mel.shape
# Out:
# (128, 1293)

# %%
img.show()

D:\Datasets\musicdata\fma_small\fma_small\000

# %%
y, sr = librosa.load(r"..\fma_small\fma_small\114\114298.mp3")

# %%
mel = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)

# %%
librosa.display.specshow(librosa.power_to_db(mel, ref=np.max), y_axis='mel', x_axis='time', cmap="gray_r")

# %%
mel.shape
# Out:
# (128, 1291)

# %%
img = Image.fromarray(librosa.power_to_db(mel, ref=np.max))

# %%
imshow(np.flip(np.asarray(img)))

# %%
n_fft = 2048
hop_length = 512
audio_stft = librosa.core.stft(y, hop_length=hop_length, n_fft=n_fft)
spectrogram = np.abs(audio_stft)
log_spectro = librosa.amplitude_to_db(spectrogram)
#Plotting the short-time Fourier Transformation
plt.figure(figsize=(20, 5))
# Using librosa.display.specshow() to create our spectrogram
librosa.display.specshow(log_spectro, sr=sr, x_axis='time', y_axis='hz', hop_length=hop_length, cmap='magma')
plt.colorbar(label='Decibels')
plt.title('Spectrogram (dB)', fontdict=dict(size=18))
plt.xlabel('Time', fontdict=dict(size=15))
plt.ylabel('Frequency', fontdict=dict(size=15))
plt.show()

# %%
# mel_signal = librosa.feature.melspectrogram(y=y, sr=sr, hop_length=hop_length, 
#  n_fft=n_fft)
# spectrogram = np.abs(mel_signal)
power_to_db = librosa.power_to_db(mel, ref=np.max)
# plt.figure(figsize=(8, 7))
librosa.display.specshow(power_to_db, sr=sr, x_axis='s', y_axis='mel', cmap='gray_r')
# plt.colorbar(label='dB')
# plt.title('Mel-Spectrogram (dB)', fontdict=dict(size=18))
# plt.xlabel('Time', fontdict=dict(size=15))
# plt.ylabel('Frequency', fontdict=dict(size=15))
# plt.show()
plt.axis('off')
plt.savefig("test.png",bbox_inches = 'tight', pad_inches = 0, vmin=0, vmax=255)
# Out:
# <ipython-input-11-7225aab6d217>:13: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "vmin" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig("test.png",bbox_inches = 'tight', pad_inches = 0, vmin=0, vmax=255)
# <ipython-input-11-7225aab6d217>:13: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "vmax" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig("test.png",bbox_inches = 'tight', pad_inches = 0, vmin=0, vmax=255)

# %%
power_to_db
# Out:
# array([[-12.169266 , -10.961374 , -11.45916  , ..., -16.270657 ,
#         -16.599693 , -16.433805 ],
#        [-11.179178 ,  -7.399973 ,  -7.049675 , ...,  -8.9948845,
#         -11.263891 ,  -8.691414 ],
#        [-21.748741 , -21.0408   , -21.125395 , ..., -14.497694 ,
#         -12.743744 , -14.861141 ],
#        ...,
#        [-80.       , -80.       , -80.       , ..., -80.       ,
#         -80.       , -80.       ],
#        [-80.       , -80.       , -80.       , ..., -80.       ,
#         -80.       , -80.       ],
#        [-80.       , -80.       , -80.       , ..., -80.       ,
#         -80.       , -80.       ]], dtype=float32)

# %%
img = Image.fromarray(power_to_db)

# %%
# from matplotlib.colors import LogNorm
# h, w = power_to_db.shape
# x = np.linspace(0, 30, w)
# y = np.logspace(1, 8, h)
# X, Y = np.meshgrid(x,y)
# im = plt.pcolor(X,Y, cmap='gray', norm=LogNorm())

# %%
plt.imshow(np.asarray(img), origin='lower',cmap=plt.get_cmap("magma") )

# %%
def scale_minmax(X, min=0.0, max=1.0):
    X_std = (X - X.min()) / (X.max() - X.min())
    X_scaled = X_std * (max - min) + min
    return X_scaled

# %%
melspectrogram = np.log(mel_signal + 1e-9)
img = scale_minmax(melspectrogram, 0, 255).astype(np.uint8)
img = np.flip(img, axis=0)
img = 255-img

img = Image.fromarray(img)

# %%
imshow(img)
